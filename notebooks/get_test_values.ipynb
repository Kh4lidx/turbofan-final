# %%
import pandas as pd
# Load the processed dataset
df = pd.read_csv('../data/train_FD001_processed.csv')

# Extract the first row, excluding ID, time cycles, and the target (RUL))
sample_row = df.drop(columns=['unit_nr', 'time_cycles', 'RUL']).iloc[0].tolist()

# Print the features as a JSON-ready list for API testing
print(f'"features": {sample_row}')
# Out:
# "features": [-0.3159796799330239, -1.3729532035104928, -1.721725391987046, -0.1342551758995678, -0.9259359643726434, -5.3290705182007506e-15, 0.1416833287165599, 1.1211405697975247, -0.516338406192186, -0.8628133152009628, -0.2664665957146243, 0.3342618401935537, -1.0588902368798727, -0.2690710403193868, -0.6038156997582514, -3.469446951953614e-18, -0.7817097857218287, 1.3484927436601943, 1.194427047890514, -2.203658430363992, -4.604031399397599, -0.0750817395808508, -4.545198609962396, -1.0094293252644144, -4.5789126591478135, -5.3290705182007506e-15, 0.0, 0.3679312714197383, -0.4598485719727295, 1.2486975732005683, -4.463970068261441, -0.5172910127620608, -4.382749226626563, -0.9457207599980036, -2.9065941038953533, -0.1998423435953562, -4.535569803543721, 0.2867558780634937, -4.531179648188211, -1.1575556261527329, -4.365027641438313, -0.2565074680770492, -2.6807249958881343, -0.6597365128263949, -4.561885945514043, -3.469446951953614e-18, 0.0, -0.9468562665901592, -4.536422115380
# ...
